# %% [markdown]
# sys module

# %%
import sys

print("hello, my name is", sys.argv[1])
# Out:
# hello, my name is --f=/run/user/1000/jupyter/runtime/kernel-v32f2b08fa603289f9f20814ac58a56928ac537a37.json
